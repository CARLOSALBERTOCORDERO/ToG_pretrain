# %%
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, BatchNormalization, ReLU, Conv2D, Dense, MaxPool2D, AvgPool2D, GlobalAvgPool2D, Concatenate

##############
import os

from os import listdir
from os.path import isfile, join
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import ResNet152

# %%
currentPath = os.getcwd()
print(currentPath)
# Out:
# C:\Users\CARLOS CORDERO\Desktop\ToG_pretrain

# %%
gpus = tensorflow.config.experimental.list_physical_devices('GPU')
print(gpus)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
trainDB = currentPath + os.sep + "train20"
valDB = currentPath + os.sep + "val20"
data_set_path = currentPath + os.sep + "fMoW" + os.sep
Resnet152WeightsPretrained = currentPath + os.sep + "resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5"
model_name = "Resnet152"
classList = os.listdir(trainDB)

img = mpimg.imread(trainDB + os.sep + "airport" + os.sep + "airport_7_8_msrgb.jpg")
imgplot = plt.imshow(img)

# %%
lr = 0.00005
batch_size = 10
num_epochs = 200
pre_train_epochs = 20

num_steps_per_epoch = 4
img_rows, img_cols, img_channel = 224, 224, 3
num_categories = len(classList)

# %%
# First LR range analysis
# tensorboardLogsPath = "logs/lrfirtsstep/" + model_name
# LR fine tunning analysis
# tensorboardLogsPath = "logs/lrfine/" + model_name + "/lr-" + str(lr)
# model graph 
tensorboardLogsPath = "logs/modelgraph/" + model_name
tensorboardCallback = tensorflow.keras.callbacks.TensorBoard(tensorboardLogsPath)

# %%
# First LR range analysis
#def scheduler(epoch):
#    return (0.5 * (10**(-1*(epoch//20))))
#lrSchcallback = tensorflow.keras.callbacks.LearningRateScheduler(scheduler)

# %%
train_data_gen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=270,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='constant',
    cval = 0.)
    
train_generator = train_data_gen.flow_from_directory(
    directory=trainDB,
    target_size=(img_cols, img_rows),
    batch_size=batch_size,
    class_mode='categorical'
)

val_data_gen = ImageDataGenerator(
    rescale=1. / 225,
)
val_generator = val_data_gen.flow_from_directory(
    directory=valDB,
    target_size=(img_cols, img_rows),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 105 images belonging to 7 classes.
# Found 34 images belonging to 7 classes.

# %%
print(train_generator.class_indices)
imgs, labels = next(train_generator)
# Out:
# {'airport': 0, 'airport_hangar': 1, 'airport_terminal': 2, 'amusement_park': 3, 'aquaculture': 4, 'archaeological_site': 5, 'barn': 6}

# %%
input = Input(shape=(img_rows, img_cols, img_channel))

# %%
def ResnetCustom(shape,pretrainedweights, input_tensor, classes):
    RN152NoTop = ResNet152(
        include_top=False, weights=pretrainedweights, input_tensor=input_tensor, input_shape=shape)
    
    RN152Out = RN152NoTop.layers[-1].output
    x = GlobalAvgPool2D()(RN152Out)
    output = Dense(classes, activation="softmax")(x)
    model = Model(input_tensor, output)
        
    return model

# %%
model = ResnetCustom((img_rows, img_cols, img_channel),Resnet152WeightsPretrained, input, num_categories)

model.summary()
#plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_relu (Activation (None, 28, 28, 128)  0           conv3_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 28, 28, 512)  0           conv3_block4_out[0][0]
#                                                                  conv3_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_out (Activation)   (None, 28, 28, 512)  0           conv3_block5_add[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block5_out[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_relu (Activation (None, 28, 28, 128)  0           conv3_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 28, 28, 512)  0           conv3_block5_out[0][0]
#                                                                  conv3_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_out (Activation)   (None, 28, 28, 512)  0           conv3_block6_add[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block6_out[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_relu (Activation (None, 28, 28, 128)  0           conv3_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_add (Add)          (None, 28, 28, 512)  0           conv3_block6_out[0][0]
#                                                                  conv3_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_out (Activation)   (None, 28, 28, 512)  0           conv3_block7_add[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block7_out[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_relu (Activation (None, 28, 28, 128)  0           conv3_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_add (Add)          (None, 28, 28, 512)  0           conv3_block7_out[0][0]
#                                                                  conv3_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_out (Activation)   (None, 28, 28, 512)  0           conv3_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 14, 14, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 14, 14, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Activation)   (None, 14, 14, 1024) 0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 14, 14, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 14, 14, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Activation)   (None, 14, 14, 1024) 0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 14, 14, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_add (Add)          (None, 14, 14, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Activation)   (None, 14, 14, 1024) 0           conv4_block9_add[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_add (Add)         (None, 14, 14, 1024) 0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Activation)  (None, 14, 14, 1024) 0           conv4_block10_add[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  conv4_block32_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block32_out (Activation)  (None, 14, 14, 1024) 0           conv4_block32_add[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block32_out[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block33_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block33_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block33_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block33_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block33_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block33_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block33_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_add (Add)         (None, 14, 14, 1024) 0           conv4_block32_out[0][0]
#                                                                  conv4_block33_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_out (Activation)  (None, 14, 14, 1024) 0           conv4_block33_add[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block33_out[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block34_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block34_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block34_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_add (Add)         (None, 14, 14, 1024) 0           conv4_block33_out[0][0]
#                                                                  conv4_block34_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_out (Activation)  (None, 14, 14, 1024) 0           conv4_block34_add[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block34_out[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block35_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block35_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block35_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_add (Add)         (None, 14, 14, 1024) 0           conv4_block34_out[0][0]
#                                                                  conv4_block35_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_out (Activation)  (None, 14, 14, 1024) 0           conv4_block35_add[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block36_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block36_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block36_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block36_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block36_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block36_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block36_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_add (Add)         (None, 14, 14, 1024) 0           conv4_block35_out[0][0]
#                                                                  conv4_block36_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_out (Activation)  (None, 14, 14, 1024) 0           conv4_block36_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 7)            14343       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 58,385,287
# Trainable params: 58,233,863
# Non-trainable params: 151,424
# __________________________________________________________________________________________________

# %%
#optimizeFunc = SGD(learning_rate=lr, momentum=0.9, nesterov=True, decay=1e-6)
# First LR range
# optimizeFunc = Adam()
optimizeFunc = Adam(learning_rate=lr)
model.compile(optimizer=optimizeFunc, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    generator=train_generator,
    validation_data=val_generator,
    steps_per_epoch=num_steps_per_epoch,
    epochs=num_epochs,
    validation_steps=num_steps_per_epoch,
    callbacks=[tensorboardCallback],
    # First LR range analysis
    #callbacks=[lrSchcallback, tensorboardCallback],
    verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-14-7da55f8bb081>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/200
# 4/4 [==============================] - 5s 1s/step - loss: 2.2811 - accuracy: 0.1000 - val_loss: 2.2130 - val_accuracy: 0.1471
# Epoch 2/200
# 4/4 [==============================] - 2s 595ms/step - loss: 2.1323 - accuracy: 0.2250 - val_loss: 2.4317 - val_accuracy: 0.0882
# Epoch 3/200
# 4/4 [==============================] - 4s 983ms/step - loss: 2.1485 - accuracy: 0.1714 - val_loss: 2.2559 - val_accuracy: 0.1471
# Epoch 4/200
# 4/4 [==============================] - 2s 596ms/step - loss: 1.9852 - accuracy: 0.3000 - val_loss: 2.2815 - val_accuracy: 0.1471
# Epoch 5/200
# 4/4 [==============================] - 2s 599ms/step - loss: 2.0949 - accuracy: 0.1750 - val_loss: 2.4179 - val_accuracy: 0.1471
# Epoch 6/200
# 4/4 [==============================] - 2s 596ms/step - loss: 1.9293 - accuracy: 0.2857 - val_loss: 2.4043 - val_accuracy: 0.1765
# Epoch 7/200
# 4/4 [==============================] - 2s 600ms/step - loss: 2.1293 - accuracy: 0.1750 - val_loss: 2.6026 - val_accuracy: 0.0882
# Epoch 8/200
# 4/4 [==============================] - 2s 538ms/step - loss: 1.9595 - accuracy: 0.2286 - val_loss: 2.4535 - val_accuracy: 0.1765
# Epoch 9/200
# 4/4 [==============================] - 2s 600ms/step - loss: 1.9318 - accuracy: 0.2000 - val_loss: 2.4921 - val_accuracy: 0.1471
# Epoch 10/200
# 4/4 [==============================] - 2s 600ms/step - loss: 1.7474 - accuracy: 0.3000 - val_loss: 2.3205 - val_accuracy: 0.1765
# Epoch 11/200
# 4/4 [==============================] - 2s 539ms/step - loss: 1.9692 - accuracy: 0.2286 - val_loss: 2.6908 - val_accuracy: 0.0882
# Epoch 12/200
# 4/4 [==============================] - 2s 597ms/step - loss: 2.0156 - accuracy: 0.2500 - val_loss: 2.5168 - val_accuracy: 0.1176
# Epoch 13/200
# 4/4 [==============================] - 2s 603ms/step - loss: 1.5961 - accuracy: 0.4750 - val_loss: 2.4965 - val_accuracy: 0.1471
# Epoch 14/200
# 4/4 [==============================] - 2s 541ms/step - loss: 1.8999 - accuracy: 0.2000 - val_loss: 2.3597 - val_accuracy: 0.2059
# Epoch 15/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.7016 - accuracy: 0.2500 - val_loss: 2.5855 - val_accuracy: 0.1471
# Epoch 16/200
# 4/4 [==============================] - 2s 596ms/step - loss: 1.6414 - accuracy: 0.4750 - val_loss: 2.5322 - val_accuracy: 0.1471
# Epoch 17/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.6092 - accuracy: 0.3429 - val_loss: 2.5467 - val_accuracy: 0.1471
# Epoch 18/200
# 4/4 [==============================] - 2s 601ms/step - loss: 1.6937 - accuracy: 0.4000 - val_loss: 2.5636 - val_accuracy: 0.1765
# Epoch 19/200
# 4/4 [==============================] - 2s 540ms/step - loss: 1.7832 - accuracy: 0.4000 - val_loss: 2.4802 - val_accuracy: 0.2059
# Epoch 20/200
# 4/4 [==============================] - 2s 599ms/step - loss: 1.6020 - accuracy: 0.4000 - val_loss: 2.6554 - val_accuracy: 0.1176
# Epoch 21/200
# 4/4 [==============================] - 2s 601ms/step - loss: 1.6046 - accuracy: 0.4250 - val_loss: 2.5228 - val_accuracy: 0.1471
# Epoch 22/200
# 4/4 [==============================] - 2s 542ms/step - loss: 1.5124 - accuracy: 0.4571 - val_loss: 2.6023 - val_accuracy: 0.1471
# Epoch 23/200
# 4/4 [==============================] - 2s 604ms/step - loss: 1.5029 - accuracy: 0.4750 - val_loss: 2.3906 - val_accuracy: 0.1765
# Epoch 24/200
# 4/4 [==============================] - 2s 601ms/step - loss: 1.4125 - accuracy: 0.4000 - val_loss: 2.3935 - val_accuracy: 0.1471
# Epoch 25/200
# 4/4 [==============================] - 2s 540ms/step - loss: 1.4055 - accuracy: 0.5143 - val_loss: 2.4685 - val_accuracy: 0.1471
# Epoch 26/200
# 4/4 [==============================] - 2s 605ms/step - loss: 1.5279 - accuracy: 0.4000 - val_loss: 2.4631 - val_accuracy: 0.1176
# Epoch 27/200
# 4/4 [==============================] - 2s 603ms/step - loss: 1.5187 - accuracy: 0.5000 - val_loss: 2.5451 - val_accuracy: 0.0882
# Epoch 28/200
# 4/4 [==============================] - 2s 599ms/step - loss: 1.4450 - accuracy: 0.5714 - val_loss: 2.2614 - val_accuracy: 0.2059
# Epoch 29/200
# 4/4 [==============================] - 2s 603ms/step - loss: 1.2545 - accuracy: 0.6500 - val_loss: 2.4213 - val_accuracy: 0.1765
# Epoch 30/200
# 4/4 [==============================] - 2s 540ms/step - loss: 1.4007 - accuracy: 0.4857 - val_loss: 2.4419 - val_accuracy: 0.2059
# Epoch 31/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.4122 - accuracy: 0.5000 - val_loss: 2.2924 - val_accuracy: 0.1765
# Epoch 32/200
# 4/4 [==============================] - 2s 600ms/step - loss: 1.4048 - accuracy: 0.4500 - val_loss: 2.2603 - val_accuracy: 0.2353
# Epoch 33/200
# 4/4 [==============================] - 2s 542ms/step - loss: 1.2426 - accuracy: 0.6286 - val_loss: 2.3828 - val_accuracy: 0.1765
# Epoch 34/200
# 4/4 [==============================] - 2s 604ms/step - loss: 1.2606 - accuracy: 0.6750 - val_loss: 2.3255 - val_accuracy: 0.2353
# Epoch 35/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.2469 - accuracy: 0.5500 - val_loss: 2.2363 - val_accuracy: 0.1765
# Epoch 36/200
# 4/4 [==============================] - 2s 540ms/step - loss: 1.2828 - accuracy: 0.6857 - val_loss: 2.3184 - val_accuracy: 0.1765
# Epoch 37/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.1554 - accuracy: 0.7250 - val_loss: 2.3436 - val_accuracy: 0.1765
# Epoch 38/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.0851 - accuracy: 0.7250 - val_loss: 2.3955 - val_accuracy: 0.1471
# Epoch 39/200
# 4/4 [==============================] - 2s 600ms/step - loss: 1.2395 - accuracy: 0.6286 - val_loss: 2.5320 - val_accuracy: 0.1471
# Epoch 40/200
# 4/4 [==============================] - 2s 597ms/step - loss: 1.2413 - accuracy: 0.6500 - val_loss: 2.2411 - val_accuracy: 0.2353
# Epoch 41/200
# 4/4 [==============================] - 2s 543ms/step - loss: 1.0933 - accuracy: 0.6000 - val_loss: 2.3703 - val_accuracy: 0.1765
# Epoch 42/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.2081 - accuracy: 0.6250 - val_loss: 2.4163 - val_accuracy: 0.1471
# Epoch 43/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.9776 - accuracy: 0.7750 - val_loss: 2.4062 - val_accuracy: 0.2059
# Epoch 44/200
# 4/4 [==============================] - 2s 541ms/step - loss: 1.1260 - accuracy: 0.6286 - val_loss: 2.4944 - val_accuracy: 0.1471
# Epoch 45/200
# 4/4 [==============================] - 2s 605ms/step - loss: 1.1440 - accuracy: 0.6000 - val_loss: 2.4157 - val_accuracy: 0.1765
# Epoch 46/200
# 4/4 [==============================] - 2s 602ms/step - loss: 1.0518 - accuracy: 0.7000 - val_loss: 2.4367 - val_accuracy: 0.1176
# Epoch 47/200
# 4/4 [==============================] - 2s 545ms/step - loss: 1.0968 - accuracy: 0.6571 - val_loss: 2.3707 - val_accuracy: 0.2059
# Epoch 48/200
# 4/4 [==============================] - 2s 603ms/step - loss: 1.1334 - accuracy: 0.6500 - val_loss: 2.4163 - val_accuracy: 0.2059
# Epoch 49/200
# 4/4 [==============================] - 2s 603ms/step - loss: 1.0737 - accuracy: 0.7750 - val_loss: 2.4357 - val_accuracy: 0.2059
# Epoch 50/200
# 4/4 [==============================] - 2s 605ms/step - loss: 1.0937 - accuracy: 0.6286 - val_loss: 2.3923 - val_accuracy: 0.2353
# Epoch 51/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.9963 - accuracy: 0.6500 - val_loss: 2.6711 - val_accuracy: 0.0882
# Epoch 52/200
# 4/4 [==============================] - 2s 540ms/step - loss: 0.9349 - accuracy: 0.7714 - val_loss: 2.2903 - val_accuracy: 0.1765
# Epoch 53/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.9872 - accuracy: 0.6750 - val_loss: 2.4716 - val_accuracy: 0.1471
# Epoch 54/200
# 4/4 [==============================] - 2s 600ms/step - loss: 1.0147 - accuracy: 0.7000 - val_loss: 2.4112 - val_accuracy: 0.1471
# Epoch 55/200
# 4/4 [==============================] - 2s 543ms/step - loss: 0.8025 - accuracy: 0.7429 - val_loss: 2.8045 - val_accuracy: 0.0588
# Epoch 56/200
# 4/4 [==============================] - 2s 601ms/step - loss: 0.7967 - accuracy: 0.7750 - val_loss: 2.3656 - val_accuracy: 0.1471
# Epoch 57/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.8282 - accuracy: 0.8250 - val_loss: 2.5271 - val_accuracy: 0.1471
# Epoch 58/200
# 4/4 [==============================] - 2s 543ms/step - loss: 1.0546 - accuracy: 0.6571 - val_loss: 2.5436 - val_accuracy: 0.0882
# Epoch 59/200
# 4/4 [==============================] - 2s 607ms/step - loss: 0.8728 - accuracy: 0.8000 - val_loss: 2.5955 - val_accuracy: 0.1765
# Epoch 60/200
# 4/4 [==============================] - 2s 602ms/step - loss: 0.8433 - accuracy: 0.8500 - val_loss: 2.5026 - val_accuracy: 0.2059
# Epoch 61/200
# 4/4 [==============================] - 2s 603ms/step - loss: 1.0299 - accuracy: 0.6000 - val_loss: 2.5637 - val_accuracy: 0.1765
# Epoch 62/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.7174 - accuracy: 0.9000 - val_loss: 2.6051 - val_accuracy: 0.0882
# Epoch 63/200
# 4/4 [==============================] - 2s 543ms/step - loss: 0.9006 - accuracy: 0.7714 - val_loss: 2.0997 - val_accuracy: 0.2647
# Epoch 64/200
# 4/4 [==============================] - 2s 601ms/step - loss: 0.8276 - accuracy: 0.7750 - val_loss: 2.4610 - val_accuracy: 0.1471
# Epoch 65/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.9668 - accuracy: 0.7500 - val_loss: 2.4052 - val_accuracy: 0.1765
# Epoch 66/200
# 4/4 [==============================] - 2s 542ms/step - loss: 0.9722 - accuracy: 0.6571 - val_loss: 2.3543 - val_accuracy: 0.1765
# Epoch 67/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.7457 - accuracy: 0.8750 - val_loss: 2.4418 - val_accuracy: 0.1471
# Epoch 68/200
# 4/4 [==============================] - 2s 601ms/step - loss: 0.8179 - accuracy: 0.8250 - val_loss: 2.6337 - val_accuracy: 0.1471
# Epoch 69/200
# 4/4 [==============================] - 2s 544ms/step - loss: 0.8340 - accuracy: 0.8000 - val_loss: 2.4666 - val_accuracy: 0.1471
# Epoch 70/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.7616 - accuracy: 0.8000 - val_loss: 2.7726 - val_accuracy: 0.0882
# Epoch 71/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.6873 - accuracy: 0.9000 - val_loss: 2.0593 - val_accuracy: 0.2647
# Epoch 72/200
# 4/4 [==============================] - 2s 603ms/step - loss: 0.7033 - accuracy: 0.8571 - val_loss: 2.5124 - val_accuracy: 0.1471
# Epoch 73/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.7085 - accuracy: 0.8750 - val_loss: 2.5657 - val_accuracy: 0.1765
# Epoch 74/200
# 4/4 [==============================] - 2s 545ms/step - loss: 0.7404 - accuracy: 0.8286 - val_loss: 2.7541 - val_accuracy: 0.0882
# Epoch 75/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.8314 - accuracy: 0.7500 - val_loss: 2.8976 - val_accuracy: 0.1471
# Epoch 76/200
# 4/4 [==============================] - 2s 601ms/step - loss: 0.6571 - accuracy: 0.8750 - val_loss: 2.7693 - val_accuracy: 0.2059
# Epoch 77/200
# 4/4 [==============================] - 2s 544ms/step - loss: 0.5585 - accuracy: 0.9143 - val_loss: 2.6868 - val_accuracy: 0.1471
# Epoch 78/200
# 4/4 [==============================] - 2s 607ms/step - loss: 0.6691 - accuracy: 0.8750 - val_loss: 2.5582 - val_accuracy: 0.2059
# Epoch 79/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.7345 - accuracy: 0.9000 - val_loss: 2.7474 - val_accuracy: 0.2647
# Epoch 80/200
# 4/4 [==============================] - 2s 541ms/step - loss: 0.6630 - accuracy: 0.9143 - val_loss: 2.8998 - val_accuracy: 0.1765
# Epoch 81/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.6214 - accuracy: 0.8500 - val_loss: 2.8181 - val_accuracy: 0.1765
# Epoch 82/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.6785 - accuracy: 0.9000 - val_loss: 3.0365 - val_accuracy: 0.1765
# Epoch 83/200
# 4/4 [==============================] - 2s 607ms/step - loss: 0.6828 - accuracy: 0.8571 - val_loss: 2.7716 - val_accuracy: 0.2353
# Epoch 84/200
# 4/4 [==============================] - 2s 603ms/step - loss: 0.6331 - accuracy: 0.8500 - val_loss: 2.7997 - val_accuracy: 0.1765
# Epoch 85/200
# 4/4 [==============================] - 2s 547ms/step - loss: 0.6099 - accuracy: 0.8857 - val_loss: 3.1125 - val_accuracy: 0.1471
# Epoch 86/200
# 4/4 [==============================] - 2s 607ms/step - loss: 0.6601 - accuracy: 0.8500 - val_loss: 3.2253 - val_accuracy: 0.2353
# Epoch 87/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.5319 - accuracy: 0.9250 - val_loss: 2.9531 - val_accuracy: 0.0588
# Epoch 88/200
# 4/4 [==============================] - 2s 540ms/step - loss: 0.5340 - accuracy: 0.9143 - val_loss: 3.1375 - val_accuracy: 0.1765
# Epoch 89/200
# 4/4 [==============================] - 2s 607ms/step - loss: 0.4267 - accuracy: 0.9750 - val_loss: 3.1493 - val_accuracy: 0.1471
# Epoch 90/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.6508 - accuracy: 0.8250 - val_loss: 2.9005 - val_accuracy: 0.2353
# Epoch 91/200
# 4/4 [==============================] - 2s 546ms/step - loss: 0.5934 - accuracy: 0.8571 - val_loss: 3.5160 - val_accuracy: 0.1471
# Epoch 92/200
# 4/4 [==============================] - 2s 603ms/step - loss: 0.5902 - accuracy: 0.9000 - val_loss: 2.7309 - val_accuracy: 0.1765
# Epoch 93/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.5090 - accuracy: 0.9250 - val_loss: 3.2448 - val_accuracy: 0.1471
# Epoch 94/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.4818 - accuracy: 0.9429 - val_loss: 3.2572 - val_accuracy: 0.1765
# Epoch 95/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.6425 - accuracy: 0.8250 - val_loss: 3.1281 - val_accuracy: 0.1471
# Epoch 96/200
# 4/4 [==============================] - 2s 543ms/step - loss: 0.7578 - accuracy: 0.6857 - val_loss: 3.4830 - val_accuracy: 0.1176
# Epoch 97/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.5096 - accuracy: 0.9500 - val_loss: 3.2115 - val_accuracy: 0.1471
# Epoch 98/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.8471 - accuracy: 0.7500 - val_loss: 2.8512 - val_accuracy: 0.1765
# Epoch 99/200
# 4/4 [==============================] - 2s 546ms/step - loss: 0.5494 - accuracy: 0.9143 - val_loss: 2.8405 - val_accuracy: 0.1765
# Epoch 100/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.5022 - accuracy: 0.9250 - val_loss: 4.0426 - val_accuracy: 0.1471
# Epoch 101/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.4216 - accuracy: 0.9500 - val_loss: 3.6215 - val_accuracy: 0.1765
# Epoch 102/200
# 4/4 [==============================] - 2s 545ms/step - loss: 0.4799 - accuracy: 0.9143 - val_loss: 4.1273 - val_accuracy: 0.1765
# Epoch 103/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.4010 - accuracy: 0.9500 - val_loss: 3.5015 - val_accuracy: 0.2059
# Epoch 104/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.5595 - accuracy: 0.9000 - val_loss: 3.9026 - val_accuracy: 0.1765
# Epoch 105/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.4163 - accuracy: 0.8857 - val_loss: 4.0519 - val_accuracy: 0.1765
# Epoch 106/200
# 4/4 [==============================] - 2s 611ms/step - loss: 0.4385 - accuracy: 0.9250 - val_loss: 4.5921 - val_accuracy: 0.1765
# Epoch 107/200
# 4/4 [==============================] - 2s 546ms/step - loss: 0.4804 - accuracy: 0.9143 - val_loss: 3.6126 - val_accuracy: 0.1765
# Epoch 108/200
# 4/4 [==============================] - 2s 604ms/step - loss: 0.5088 - accuracy: 0.8500 - val_loss: 4.5725 - val_accuracy: 0.1176
# Epoch 109/200
# 4/4 [==============================] - 2s 607ms/step - loss: 0.4537 - accuracy: 0.9750 - val_loss: 4.7024 - val_accuracy: 0.1765
# Epoch 110/200
# 4/4 [==============================] - 2s 546ms/step - loss: 0.4361 - accuracy: 0.9429 - val_loss: 6.1089 - val_accuracy: 0.1471
# Epoch 111/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.4085 - accuracy: 0.9250 - val_loss: 4.5672 - val_accuracy: 0.2353
# Epoch 112/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.5154 - accuracy: 0.9000 - val_loss: 5.5366 - val_accuracy: 0.1765
# Epoch 113/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.4234 - accuracy: 0.9714 - val_loss: 5.5969 - val_accuracy: 0.1765
# Epoch 114/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.5277 - accuracy: 0.9000 - val_loss: 3.7690 - val_accuracy: 0.1471
# Epoch 115/200
# 4/4 [==============================] - 2s 613ms/step - loss: 0.4073 - accuracy: 0.8750 - val_loss: 5.5427 - val_accuracy: 0.2353
# Epoch 116/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.4773 - accuracy: 0.8857 - val_loss: 5.6454 - val_accuracy: 0.1471
# Epoch 117/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.4028 - accuracy: 1.0000 - val_loss: 5.9702 - val_accuracy: 0.1765
# Epoch 118/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.3753 - accuracy: 0.9143 - val_loss: 5.4378 - val_accuracy: 0.1471
# Epoch 119/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.4775 - accuracy: 0.8750 - val_loss: 6.3576 - val_accuracy: 0.1765
# Epoch 120/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.3959 - accuracy: 0.9250 - val_loss: 6.8222 - val_accuracy: 0.1765
# Epoch 121/200
# 4/4 [==============================] - 2s 546ms/step - loss: 0.3894 - accuracy: 0.9143 - val_loss: 5.9784 - val_accuracy: 0.1765
# Epoch 122/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.4303 - accuracy: 0.9500 - val_loss: 5.9243 - val_accuracy: 0.2353
# Epoch 123/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.4159 - accuracy: 0.9000 - val_loss: 4.8358 - val_accuracy: 0.1176
# Epoch 124/200
# 4/4 [==============================] - 2s 542ms/step - loss: 0.3778 - accuracy: 0.9429 - val_loss: 6.9009 - val_accuracy: 0.2059
# Epoch 125/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.4055 - accuracy: 0.9000 - val_loss: 6.2545 - val_accuracy: 0.1765
# Epoch 126/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.3399 - accuracy: 0.8750 - val_loss: 7.5298 - val_accuracy: 0.1471
# Epoch 127/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.4393 - accuracy: 0.8571 - val_loss: 6.7366 - val_accuracy: 0.1765
# Epoch 128/200
# 4/4 [==============================] - 2s 605ms/step - loss: 0.3771 - accuracy: 0.9250 - val_loss: 5.7361 - val_accuracy: 0.1471
# Epoch 129/200
# 4/4 [==============================] - 2s 551ms/step - loss: 0.3944 - accuracy: 0.9429 - val_loss: 6.5432 - val_accuracy: 0.1765
# Epoch 130/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.3311 - accuracy: 0.9500 - val_loss: 7.0049 - val_accuracy: 0.1471
# Epoch 131/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.2356 - accuracy: 1.0000 - val_loss: 7.5128 - val_accuracy: 0.2353
# Epoch 132/200
# 4/4 [==============================] - 2s 546ms/step - loss: 0.3306 - accuracy: 0.9429 - val_loss: 6.9894 - val_accuracy: 0.1471
# Epoch 133/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2326 - accuracy: 0.9750 - val_loss: 6.9817 - val_accuracy: 0.1765
# Epoch 134/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.3851 - accuracy: 0.8750 - val_loss: 7.8980 - val_accuracy: 0.1765
# Epoch 135/200
# 4/4 [==============================] - 2s 549ms/step - loss: 0.3636 - accuracy: 0.9429 - val_loss: 7.1732 - val_accuracy: 0.2059
# Epoch 136/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.3090 - accuracy: 0.9500 - val_loss: 6.4475 - val_accuracy: 0.2059
# Epoch 137/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.3247 - accuracy: 0.9500 - val_loss: 7.5695 - val_accuracy: 0.2059
# Epoch 138/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.3986 - accuracy: 0.9143 - val_loss: 8.8078 - val_accuracy: 0.1765
# Epoch 139/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2392 - accuracy: 0.9750 - val_loss: 6.6094 - val_accuracy: 0.2647
# Epoch 140/200
# 4/4 [==============================] - 2s 542ms/step - loss: 0.2680 - accuracy: 0.9714 - val_loss: 8.5145 - val_accuracy: 0.2353
# Epoch 141/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.2703 - accuracy: 0.9750 - val_loss: 8.0600 - val_accuracy: 0.2353
# Epoch 142/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.2438 - accuracy: 0.9750 - val_loss: 8.0027 - val_accuracy: 0.3824
# Epoch 143/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.2780 - accuracy: 1.0000 - val_loss: 5.7244 - val_accuracy: 0.2059
# Epoch 144/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.2339 - accuracy: 1.0000 - val_loss: 6.6462 - val_accuracy: 0.2647
# Epoch 145/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2162 - accuracy: 0.9750 - val_loss: 7.8607 - val_accuracy: 0.2353
# Epoch 146/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.2928 - accuracy: 0.9714 - val_loss: 9.0905 - val_accuracy: 0.2353
# Epoch 147/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2632 - accuracy: 0.9750 - val_loss: 7.6065 - val_accuracy: 0.1765
# Epoch 148/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.3143 - accuracy: 0.9500 - val_loss: 8.9848 - val_accuracy: 0.2353
# Epoch 149/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.2921 - accuracy: 1.0000 - val_loss: 9.6490 - val_accuracy: 0.2353
# Epoch 150/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.3600 - accuracy: 0.8750 - val_loss: 9.9208 - val_accuracy: 0.2353
# Epoch 151/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.3264 - accuracy: 0.9429 - val_loss: 9.6617 - val_accuracy: 0.2353
# Epoch 152/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.1837 - accuracy: 1.0000 - val_loss: 11.1653 - val_accuracy: 0.2353
# Epoch 153/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.2128 - accuracy: 0.9750 - val_loss: 10.4167 - val_accuracy: 0.2353
# Epoch 154/200
# 4/4 [==============================] - 2s 546ms/step - loss: 0.3187 - accuracy: 0.9429 - val_loss: 10.7778 - val_accuracy: 0.1765
# Epoch 155/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2477 - accuracy: 0.9500 - val_loss: 8.3423 - val_accuracy: 0.2353
# Epoch 156/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.3490 - accuracy: 0.9000 - val_loss: 8.7469 - val_accuracy: 0.2941
# Epoch 157/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.2498 - accuracy: 0.9429 - val_loss: 9.2499 - val_accuracy: 0.2353
# Epoch 158/200
# 4/4 [==============================] - 2s 613ms/step - loss: 0.2617 - accuracy: 0.9500 - val_loss: 8.6824 - val_accuracy: 0.2059
# Epoch 159/200
# 4/4 [==============================] - 2s 613ms/step - loss: 0.2298 - accuracy: 1.0000 - val_loss: 7.1321 - val_accuracy: 0.2941
# Epoch 160/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2043 - accuracy: 0.9714 - val_loss: 9.0445 - val_accuracy: 0.2353
# Epoch 161/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2120 - accuracy: 1.0000 - val_loss: 8.7260 - val_accuracy: 0.2353
# Epoch 162/200
# 4/4 [==============================] - 2s 549ms/step - loss: 0.2741 - accuracy: 0.9429 - val_loss: 9.5404 - val_accuracy: 0.2353
# Epoch 163/200
# 4/4 [==============================] - 2s 613ms/step - loss: 0.2014 - accuracy: 0.9750 - val_loss: 8.7459 - val_accuracy: 0.2941
# Epoch 164/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.3329 - accuracy: 0.9250 - val_loss: 7.3110 - val_accuracy: 0.2353
# Epoch 165/200
# 4/4 [==============================] - 2s 556ms/step - loss: 0.2695 - accuracy: 0.9714 - val_loss: 9.5435 - val_accuracy: 0.2353
# Epoch 166/200
# 4/4 [==============================] - 2s 611ms/step - loss: 0.2146 - accuracy: 0.9500 - val_loss: 10.0996 - val_accuracy: 0.2059
# Epoch 167/200
# 4/4 [==============================] - 2s 611ms/step - loss: 0.2217 - accuracy: 1.0000 - val_loss: 11.4317 - val_accuracy: 0.2647
# Epoch 168/200
# 4/4 [==============================] - 2s 547ms/step - loss: 0.2912 - accuracy: 0.9714 - val_loss: 10.6381 - val_accuracy: 0.1765
# Epoch 169/200
# 4/4 [==============================] - 2s 614ms/step - loss: 0.1651 - accuracy: 1.0000 - val_loss: 10.6435 - val_accuracy: 0.2353
# Epoch 170/200
# 4/4 [==============================] - 2s 610ms/step - loss: 0.1315 - accuracy: 1.0000 - val_loss: 10.8125 - val_accuracy: 0.2353
# Epoch 171/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.2194 - accuracy: 1.0000 - val_loss: 9.3060 - val_accuracy: 0.2353
# Epoch 172/200
# 4/4 [==============================] - 2s 610ms/step - loss: 0.1620 - accuracy: 0.9750 - val_loss: 10.5281 - val_accuracy: 0.2059
# Epoch 173/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.2025 - accuracy: 1.0000 - val_loss: 9.6176 - val_accuracy: 0.2353
# Epoch 174/200
# 4/4 [==============================] - 2s 610ms/step - loss: 0.2280 - accuracy: 0.9750 - val_loss: 11.1251 - val_accuracy: 0.2647
# Epoch 175/200
# 4/4 [==============================] - 2s 611ms/step - loss: 0.1850 - accuracy: 1.0000 - val_loss: 7.4818 - val_accuracy: 0.2941
# Epoch 176/200
# 4/4 [==============================] - 2s 548ms/step - loss: 0.1979 - accuracy: 0.9714 - val_loss: 10.9495 - val_accuracy: 0.2059
# Epoch 177/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.1768 - accuracy: 1.0000 - val_loss: 10.2352 - val_accuracy: 0.2353
# Epoch 178/200
# 4/4 [==============================] - 2s 611ms/step - loss: 0.1392 - accuracy: 0.9500 - val_loss: 11.6226 - val_accuracy: 0.2059
# Epoch 179/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.1867 - accuracy: 1.0000 - val_loss: 11.7564 - val_accuracy: 0.2059
# Epoch 180/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.2444 - accuracy: 0.9500 - val_loss: 11.1225 - val_accuracy: 0.2059
# Epoch 181/200
# 4/4 [==============================] - 2s 611ms/step - loss: 0.2055 - accuracy: 0.9750 - val_loss: 10.7806 - val_accuracy: 0.2059
# Epoch 182/200
# 4/4 [==============================] - 2s 613ms/step - loss: 0.2052 - accuracy: 1.0000 - val_loss: 10.2990 - val_accuracy: 0.2353
# Epoch 183/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.2831 - accuracy: 0.9500 - val_loss: 10.6608 - val_accuracy: 0.2353
# Epoch 184/200
# 4/4 [==============================] - 2s 545ms/step - loss: 0.1871 - accuracy: 0.9714 - val_loss: 10.1718 - val_accuracy: 0.2059
# Epoch 185/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.1795 - accuracy: 0.9750 - val_loss: 9.7164 - val_accuracy: 0.2353
# Epoch 186/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.0944 - accuracy: 1.0000 - val_loss: 10.9738 - val_accuracy: 0.2059
# Epoch 187/200
# 4/4 [==============================] - 2s 549ms/step - loss: 0.1756 - accuracy: 1.0000 - val_loss: 9.9490 - val_accuracy: 0.1765
# Epoch 188/200
# 4/4 [==============================] - 2s 611ms/step - loss: 0.1777 - accuracy: 1.0000 - val_loss: 10.1649 - val_accuracy: 0.2059
# Epoch 189/200
# 4/4 [==============================] - 2s 610ms/step - loss: 0.0991 - accuracy: 1.0000 - val_loss: 9.3194 - val_accuracy: 0.2353
# Epoch 190/200
# 4/4 [==============================] - 2s 550ms/step - loss: 0.1594 - accuracy: 1.0000 - val_loss: 9.6576 - val_accuracy: 0.2647
# Epoch 191/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.1491 - accuracy: 1.0000 - val_loss: 9.5486 - val_accuracy: 0.2353
# Epoch 192/200
# 4/4 [==============================] - 2s 607ms/step - loss: 0.1625 - accuracy: 0.9750 - val_loss: 9.1115 - val_accuracy: 0.2647
# Epoch 193/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.1482 - accuracy: 1.0000 - val_loss: 8.7945 - val_accuracy: 0.2353
# Epoch 194/200
# 4/4 [==============================] - 2s 608ms/step - loss: 0.1234 - accuracy: 1.0000 - val_loss: 8.5670 - val_accuracy: 0.2059
# Epoch 195/200
# 4/4 [==============================] - 2s 551ms/step - loss: 0.2019 - accuracy: 0.9714 - val_loss: 8.5698 - val_accuracy: 0.2059
# Epoch 196/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.1374 - accuracy: 1.0000 - val_loss: 8.5611 - val_accuracy: 0.2941
# Epoch 197/200
# 4/4 [==============================] - 2s 612ms/step - loss: 0.1400 - accuracy: 1.0000 - val_loss: 9.2637 - val_accuracy: 0.2353
# Epoch 198/200
# 4/4 [==============================] - 2s 548ms/step - loss: 0.2374 - accuracy: 1.0000 - val_loss: 8.0630 - val_accuracy: 0.2059
# Epoch 199/200
# 4/4 [==============================] - 2s 610ms/step - loss: 0.1284 - accuracy: 1.0000 - val_loss: 11.2047 - val_accuracy: 0.2059
# Epoch 200/200
# 4/4 [==============================] - 2s 609ms/step - loss: 0.1785 - accuracy: 0.9750 - val_loss: 9.4325 - val_accuracy: 0.2647

# %%
model.save(currentPath + os.sep + "Resnet152Model.h5")
model.save_weights(currentPath + os.sep + "Resnet152Weights.h5")

# %%
# Lets plot the results
print(history.history.keys())
# history accuracy
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("model accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.grid()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# history accuracy
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.grid()
plt.show()

# %%
# Lets predict
path = valDB + os.sep + "airport" + os.sep
imagesPredict = [f for f in listdir(path) if isfile(join(path,f))]

for file in imagesPredict:
    img = load_img(path + file, target_size=( img_rows, img_cols))
    tensorImage = img_to_array(img) /255.
    tensorImage = np.expand_dims(tensorImage, axis=0)
    prediction = model.predict(tensorImage, batch_size = 1)
    index = np.where(prediction[0] == max(prediction[0]))[0]
    if (0 != index[0].size):
        print("file "+ file + " is: " + classList[int(index[0])])
# Out:
# file airport_26_1_msrgb.jpg is: airport
# file airport_45_3_msrgb.jpg is: airport
# file airport_55_0_msrgb.jpg is: airport
# file airport_6_0_msrgb.jpg is: airport

# %%
loadedModel = load_model("Resnet152Model.h5")

path = valDB + os.sep + "airport" + os.sep
imagesPredict = [f for f in listdir(path) if isfile(join(path,f))]
# print(imagesPredict)


for file in imagesPredict:
    img = load_img(path + file, target_size=( img_rows, img_cols))
    tensorImage = img_to_array(img) /255.
    tensorImage = np.expand_dims(tensorImage, axis=0)
    prediction = loadedModel.predict(tensorImage, batch_size = 1)
    index = np.where(prediction[0] == max(prediction[0]))[0]
    if (0 != index[0].size):
        print("file "+ file + " is: " + classList[int(index[0])])
# Out:
# file airport_26_1_msrgb.jpg is: airport
# file airport_45_3_msrgb.jpg is: airport
# file airport_55_0_msrgb.jpg is: airport
# file airport_6_0_msrgb.jpg is: airport
