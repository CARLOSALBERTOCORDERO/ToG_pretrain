# %%
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, BatchNormalization, ReLU, Conv2D, Dense, MaxPool2D, AvgPool2D, GlobalAvgPool2D, Concatenate, ZeroPadding2D

##############
import os

from os import listdir
from os.path import isfile, join
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import load_model

# %%
currentPath = os.getcwd()
print(currentPath)
# Out:
# C:\Users\CARLOS CORDERO\Desktop\ToG_pretrain

# %%
gpus = tensorflow.config.experimental.list_physical_devices('GPU')
print(gpus)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
trainDB = currentPath + os.sep + "train20"
valDB = currentPath + os.sep + "val20"
data_set_path = currentPath + os.sep + "fMoW" + os.sep
DenseNetWeightsPretrained = currentPath + os.sep + "DenseNet-BC-161-48-no-top.h5"
model_name = "DenseNet-161"
classList = os.listdir(trainDB)

img = mpimg.imread(trainDB + os.sep + "airport" + os.sep + "airport_7_8_msrgb.jpg")
imgplot = plt.imshow(img)

# %%
lr = 0.000005
batch_size = 10
num_epochs = 220
pre_train_epochs = 20

num_steps_per_epoch = 4
img_rows, img_cols, img_channel = 224, 224, 3
num_categories = len(classList)

# %%
# First LR range analysis
# tensorboardLogsPath = "logs/lrfirtsstep/" + model_name
# LR fine tunning analysis
# tensorboardLogsPath = "logs/lrfine/" + model_name + "/lr-" + str(lr)
# model graph 
tensorboardLogsPath = "logs/modelgraph/" + model_name
tensorboardCallback = tensorflow.keras.callbacks.TensorBoard(tensorboardLogsPath)

# %%
# First LR range analysis
#def scheduler(epoch):
#    return (0.5 * (10**(-1*(epoch//20))))
#lrSchcallback = tensorflow.keras.callbacks.LearningRateScheduler(scheduler)

# %%
train_data_gen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=270,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='constant',
    cval = 0.)
    
train_generator = train_data_gen.flow_from_directory(
    directory=trainDB,
    target_size=(img_cols, img_rows),
    batch_size=batch_size,
    class_mode='categorical'
)

val_data_gen = ImageDataGenerator(
    rescale=1. / 225,
)
val_generator = val_data_gen.flow_from_directory(
    directory=valDB,
    target_size=(img_cols, img_rows),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 105 images belonging to 7 classes.
# Found 34 images belonging to 7 classes.

# %%
print(train_generator.class_indices)
imgs, labels = next(train_generator)
# Out:
# {'airport': 0, 'airport_hangar': 1, 'airport_terminal': 2, 'amusement_park': 3, 'aquaculture': 4, 'archaeological_site': 5, 'barn': 6}

# %%
convcnt = 1
def bn_relu_conv(x, filters, kernel_size):
    global convcnt
    convcnt = convcnt + 1
    x = BatchNormalization(name= "batch_normalization_"+str(convcnt))(x)
    x = ReLU()(x) 
    x = Conv2D(filters, kernel_size, padding="same", name= "conv2d_"+str(convcnt), use_bias=False)(x)
    return x

# %%
def dense_block(tensor, k, reps):
    for _ in range(reps):
        x = bn_relu_conv(tensor, 4*k, 1)
        x = bn_relu_conv(x, k, 3)
        tensor = Concatenate()([tensor, x])
    return tensor

# %%
def transition_layer(x, theta):
    f = int(tensorflow.keras.backend.int_shape(x)[-1] * theta)
    x = bn_relu_conv(x, f, 1)
    x = AvgPool2D(2, strides=2, padding="same")(x)
    return x

# %%
def densenet_161( imageShape, weights):
    k = 48
    theta = 0.5
    repetitions = [6, 12, 36, 24]

    input = Input(shape=(imageShape))
    x = ZeroPadding2D(padding=(3, 3))(input)
    x = Conv2D(2*k, 7, strides=2, padding="valid", name="conv2d_1", use_bias=False)(x)
    x = BatchNormalization(name= "batch_normalization_input")(x)
    x = ReLU()(x)
    x = ZeroPadding2D(padding=(1, 1))(x)
    x = MaxPool2D(3, strides=2, padding="valid")(x)

    for reps in repetitions:
        denseBlock = dense_block(x, k, reps)
        x = transition_layer(denseBlock, theta)

    model = Model(input, denseBlock)
    model.load_weights(weights, by_name=True)
    
    x = GlobalAvgPool2D()(denseBlock)
    output = Dense(num_categories, activation="softmax")(x)
    model = Model(input, output)
        
    return model

# %%
model = densenet_161((img_rows, img_cols, img_channel), DenseNetWeightsPretrained)

model.summary()
#plot_model(model, show_shapes=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 96) 14112       zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_input (Batc (None, 112, 112, 96) 384         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 112, 112, 96) 0           batch_normalization_input[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 114, 114, 96) 0           re_lu[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 96)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 96)   384         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 56, 56, 96)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 192)  18432       re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 192)  768         conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 56, 56, 192)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 48)   82944       re_lu_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 144)  0           max_pooling2d[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 144)  576         concatenate[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 56, 56, 144)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 192)  27648       re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 192)  768         conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 56, 56, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 48)   82944       re_lu_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 192)  0           concatenate[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 192)  768         concatenate_1[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 56, 56, 192)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 192)  36864       re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 192)  768         conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 56, 56, 192)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 48)   82944       re_lu_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 240)  0           concatenate_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 240)  960         concatenate_2[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 56, 56, 240)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 192)  46080       re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 192)  768         conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 56, 56, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 48)   82944       re_lu_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 288)  0           concatenate_2[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 288)  1152        concatenate_3[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 56, 56, 288)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 192)  55296       re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 192)  768         conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 56, 56, 192)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 48)   82944       re_lu_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 336)  0           concatenate_3[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 336)  1344        concatenate_4[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 56, 56, 336)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 192)  64512       re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 192)  768         conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 56, 56, 192)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 48)   82944       re_lu_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 384)  0           concatenate_4[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 56, 56, 384)  1536        concatenate_5[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 56, 56, 384)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 192)  73728       re_lu_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 28, 28, 192)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 192)  768         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 192)  36864       re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 192)  768         conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 240)  0           average_pooling2d[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 240)  960         concatenate_6[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 28, 28, 240)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 192)  46080       re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 192)  768         conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 288)  0           concatenate_6[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 288)  1152        concatenate_7[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 28, 28, 288)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 192)  55296       re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 192)  768         conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 336)  0           concatenate_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 336)  1344        concatenate_8[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 28, 28, 336)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 192)  64512       re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 192)  768         conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 384)  0           concatenate_8[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 384)  1536        concatenate_9[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 28, 28, 384)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 192)  73728       re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 192)  768         conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 432)  0           concatenate_9[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 432)  1728        concatenate_10[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 28, 28, 432)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 192)  82944       re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 192)  768         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 480)  0           concatenate_10[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 480)  1920        concatenate_11[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 28, 28, 480)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 192)  92160       re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 192)  768         conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_27[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 528)  0           concatenate_11[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 528)  2112        concatenate_12[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 28, 28, 528)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 192)  101376      re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 192)  768         conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_29[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 28, 28, 576)  0           concatenate_12[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 576)  2304        concatenate_13[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 28, 28, 576)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 192)  110592      re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 192)  768         conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 28, 28, 624)  0           concatenate_13[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 624)  2496        concatenate_14[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 28, 28, 624)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 192)  119808      re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 28, 28, 192)  768         conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_33[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 672)  0           concatenate_14[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 28, 28, 672)  2688        concatenate_15[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 28, 28, 672)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 192)  129024      re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 28, 28, 192)  768         conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 28, 28, 720)  0           concatenate_15[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 28, 28, 720)  2880        concatenate_16[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 28, 28, 720)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 28, 28, 192)  138240      re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 28, 28, 192)  768         conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 28, 28, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 28, 28, 48)   82944       re_lu_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 28, 28, 768)  0           concatenate_16[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 28, 28, 768)  3072        concatenate_17[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 28, 28, 768)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 28, 28, 384)  294912      re_lu_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 14, 14, 384)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 384)  1536        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 14, 14, 384)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 192)  73728       re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 192)  768         conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_40[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 14, 14, 432)  0           average_pooling2d_1[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 432)  1728        concatenate_18[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 14, 14, 432)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 192)  82944       re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 192)  768         conv2d_42[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_42[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 480)  0           concatenate_18[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 14, 14, 480)  1920        concatenate_19[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 14, 14, 480)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 192)  92160       re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 14, 14, 192)  768         conv2d_44[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_44[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 528)  0           concatenate_19[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 14, 14, 528)  2112        concatenate_20[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 14, 14, 528)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 192)  101376      re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 14, 14, 192)  768         conv2d_46[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 576)  0           concatenate_20[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 14, 14, 576)  2304        concatenate_21[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 14, 14, 576)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 192)  110592      re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 14, 14, 192)  768         conv2d_48[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_48[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 14, 14, 624)  0           concatenate_21[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 14, 14, 624)  2496        concatenate_22[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 14, 14, 624)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 192)  119808      re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 14, 14, 192)  768         conv2d_50[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_50[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 14, 14, 672)  0           concatenate_22[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 14, 14, 672)  2688        concatenate_23[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 14, 14, 672)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 14, 14, 192)  129024      re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 192)  768         conv2d_52[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_52[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 14, 14, 720)  0           concatenate_23[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 720)  2880        concatenate_24[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 14, 14, 720)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 14, 14, 192)  138240      re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 14, 14, 192)  768         conv2d_54[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_54[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 14, 14, 768)  0           concatenate_24[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 14, 14, 768)  3072        concatenate_25[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 14, 14, 768)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 192)  147456      re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 192)  768         conv2d_56[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_56[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 14, 14, 816)  0           concatenate_25[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 14, 14, 816)  3264        concatenate_26[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 14, 14, 816)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 14, 14, 192)  156672      re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 14, 14, 192)  768         conv2d_58[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_58[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 14, 14, 864)  0           concatenate_26[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 14, 14, 864)  3456        concatenate_27[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, 14, 14, 864)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 192)  165888      re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 14, 14, 192)  768         conv2d_60[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_60[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 14, 14, 912)  0           concatenate_27[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 14, 14, 912)  3648        concatenate_28[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, 14, 14, 912)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 14, 14, 192)  175104      re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 14, 14, 192)  768         conv2d_62[0][0]
# __________________________________________________________________________________________________
# re_lu_62 (ReLU)                 (None, 14, 14, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 14, 14, 48)   82944       re_lu_62[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 14, 14, 960)  0           concatenate_28[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 14, 14, 960)  3840        concatenate_29[0][0]
# ...
# conv2d_140 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_139[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 7, 7, 1728)   0           concatenate_66[0][0]
#                                                                  conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 7, 7, 1728)   6912        concatenate_67[0][0]
# __________________________________________________________________________________________________
# re_lu_140 (ReLU)                (None, 7, 7, 1728)   0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 7, 7, 192)    331776      re_lu_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 7, 7, 192)    768         conv2d_141[0][0]
# __________________________________________________________________________________________________
# re_lu_141 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_141[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 7, 7, 1776)   0           concatenate_67[0][0]
#                                                                  conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 7, 7, 1776)   7104        concatenate_68[0][0]
# __________________________________________________________________________________________________
# re_lu_142 (ReLU)                (None, 7, 7, 1776)   0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 7, 7, 192)    340992      re_lu_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 7, 7, 192)    768         conv2d_143[0][0]
# __________________________________________________________________________________________________
# re_lu_143 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_143[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 7, 7, 1824)   0           concatenate_68[0][0]
#                                                                  conv2d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 7, 7, 1824)   7296        concatenate_69[0][0]
# __________________________________________________________________________________________________
# re_lu_144 (ReLU)                (None, 7, 7, 1824)   0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 7, 7, 192)    350208      re_lu_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 7, 7, 192)    768         conv2d_145[0][0]
# __________________________________________________________________________________________________
# re_lu_145 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_145[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 7, 7, 1872)   0           concatenate_69[0][0]
#                                                                  conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 7, 7, 1872)   7488        concatenate_70[0][0]
# __________________________________________________________________________________________________
# re_lu_146 (ReLU)                (None, 7, 7, 1872)   0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 7, 7, 192)    359424      re_lu_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 7, 7, 192)    768         conv2d_147[0][0]
# __________________________________________________________________________________________________
# re_lu_147 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_147[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 7, 7, 1920)   0           concatenate_70[0][0]
#                                                                  conv2d_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 7, 7, 1920)   7680        concatenate_71[0][0]
# __________________________________________________________________________________________________
# re_lu_148 (ReLU)                (None, 7, 7, 1920)   0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 7, 7, 192)    368640      re_lu_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 7, 7, 192)    768         conv2d_149[0][0]
# __________________________________________________________________________________________________
# re_lu_149 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_149[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 7, 7, 1968)   0           concatenate_71[0][0]
#                                                                  conv2d_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 7, 7, 1968)   7872        concatenate_72[0][0]
# __________________________________________________________________________________________________
# re_lu_150 (ReLU)                (None, 7, 7, 1968)   0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 7, 7, 192)    377856      re_lu_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 7, 7, 192)    768         conv2d_151[0][0]
# __________________________________________________________________________________________________
# re_lu_151 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_151[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 7, 7, 2016)   0           concatenate_72[0][0]
#                                                                  conv2d_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 7, 7, 2016)   8064        concatenate_73[0][0]
# __________________________________________________________________________________________________
# re_lu_152 (ReLU)                (None, 7, 7, 2016)   0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 7, 7, 192)    387072      re_lu_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 7, 7, 192)    768         conv2d_153[0][0]
# __________________________________________________________________________________________________
# re_lu_153 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_153[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 7, 7, 2064)   0           concatenate_73[0][0]
#                                                                  conv2d_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 7, 7, 2064)   8256        concatenate_74[0][0]
# __________________________________________________________________________________________________
# re_lu_154 (ReLU)                (None, 7, 7, 2064)   0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 7, 7, 192)    396288      re_lu_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 7, 7, 192)    768         conv2d_155[0][0]
# __________________________________________________________________________________________________
# re_lu_155 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_155[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 7, 7, 2112)   0           concatenate_74[0][0]
#                                                                  conv2d_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 7, 7, 2112)   8448        concatenate_75[0][0]
# __________________________________________________________________________________________________
# re_lu_156 (ReLU)                (None, 7, 7, 2112)   0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 7, 7, 192)    405504      re_lu_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 7, 7, 192)    768         conv2d_157[0][0]
# __________________________________________________________________________________________________
# re_lu_157 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_157[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 7, 7, 2160)   0           concatenate_75[0][0]
#                                                                  conv2d_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 7, 7, 2160)   8640        concatenate_76[0][0]
# __________________________________________________________________________________________________
# re_lu_158 (ReLU)                (None, 7, 7, 2160)   0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 7, 7, 192)    414720      re_lu_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 7, 7, 192)    768         conv2d_159[0][0]
# __________________________________________________________________________________________________
# re_lu_159 (ReLU)                (None, 7, 7, 192)    0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 7, 7, 48)     82944       re_lu_159[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 7, 7, 2208)   0           concatenate_76[0][0]
#                                                                  conv2d_160[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2208)         0           concatenate_77[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 7)            15463       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 26,698,567
# Trainable params: 26,483,047
# Non-trainable params: 215,520
# __________________________________________________________________________________________________

# %%
#optimizeFunc = SGD(learning_rate=lr, momentum=0.9, nesterov=True, decay=1e-6)
# First LR range
# optimizeFunc = Adam()
optimizeFunc = Adam(learning_rate=lr)
model.compile(optimizer=optimizeFunc, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit_generator(
    generator=train_generator,
    validation_data=val_generator,
    steps_per_epoch=num_steps_per_epoch,
    epochs=num_epochs,
    validation_steps=num_steps_per_epoch,
    callbacks=[tensorboardCallback],
    # First LR range analysis
    #callbacks=[lrSchcallback, tensorboardCallback],
    verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-16-7da55f8bb081>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/220
# 4/4 [==============================] - 8s 2s/step - loss: 1.9454 - accuracy: 0.2000 - val_loss: 1.9502 - val_accuracy: 0.1471
# Epoch 2/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.9529 - accuracy: 0.0500 - val_loss: 1.9588 - val_accuracy: 0.0882
# Epoch 3/220
# 4/4 [==============================] - 12s 3s/step - loss: 1.9468 - accuracy: 0.1429 - val_loss: 1.9470 - val_accuracy: 0.1176
# Epoch 4/220
# 4/4 [==============================] - 2s 493ms/step - loss: 1.9410 - accuracy: 0.1500 - val_loss: 1.9474 - val_accuracy: 0.1471
# Epoch 5/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.9463 - accuracy: 0.1250 - val_loss: 1.9485 - val_accuracy: 0.1471
# Epoch 6/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.9372 - accuracy: 0.2000 - val_loss: 1.9530 - val_accuracy: 0.1471
# Epoch 7/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.9399 - accuracy: 0.1750 - val_loss: 1.9433 - val_accuracy: 0.1765
# Epoch 8/220
# 4/4 [==============================] - 2s 437ms/step - loss: 1.9469 - accuracy: 0.0571 - val_loss: 1.9478 - val_accuracy: 0.1471
# Epoch 9/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.9393 - accuracy: 0.1500 - val_loss: 1.9473 - val_accuracy: 0.1471
# Epoch 10/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.9352 - accuracy: 0.1750 - val_loss: 1.9484 - val_accuracy: 0.1471
# Epoch 11/220
# 4/4 [==============================] - 2s 441ms/step - loss: 1.9368 - accuracy: 0.1143 - val_loss: 1.9445 - val_accuracy: 0.1471
# Epoch 12/220
# 4/4 [==============================] - 2s 494ms/step - loss: 1.9377 - accuracy: 0.1000 - val_loss: 1.9518 - val_accuracy: 0.0882
# Epoch 13/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.9314 - accuracy: 0.2250 - val_loss: 1.9457 - val_accuracy: 0.1471
# Epoch 14/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.9323 - accuracy: 0.1143 - val_loss: 1.9506 - val_accuracy: 0.1176
# Epoch 15/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.9261 - accuracy: 0.2000 - val_loss: 1.9347 - val_accuracy: 0.2059
# Epoch 16/220
# 4/4 [==============================] - 2s 493ms/step - loss: 1.9401 - accuracy: 0.0500 - val_loss: 1.9517 - val_accuracy: 0.1176
# Epoch 17/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.9276 - accuracy: 0.2000 - val_loss: 1.9438 - val_accuracy: 0.1471
# Epoch 18/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.9248 - accuracy: 0.2250 - val_loss: 1.9505 - val_accuracy: 0.1176
# Epoch 19/220
# 4/4 [==============================] - 2s 441ms/step - loss: 1.9277 - accuracy: 0.0857 - val_loss: 1.9421 - val_accuracy: 0.1471
# Epoch 20/220
# 4/4 [==============================] - 2s 494ms/step - loss: 1.9223 - accuracy: 0.1500 - val_loss: 1.9437 - val_accuracy: 0.1471
# Epoch 21/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.9207 - accuracy: 0.2250 - val_loss: 1.9412 - val_accuracy: 0.1471
# Epoch 22/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.9289 - accuracy: 0.0571 - val_loss: 1.9379 - val_accuracy: 0.0882
# Epoch 23/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.9207 - accuracy: 0.2250 - val_loss: 1.9371 - val_accuracy: 0.1471
# Epoch 24/220
# 4/4 [==============================] - 2s 494ms/step - loss: 1.9181 - accuracy: 0.1750 - val_loss: 1.9310 - val_accuracy: 0.1471
# Epoch 25/220
# 4/4 [==============================] - 2s 441ms/step - loss: 1.9210 - accuracy: 0.1714 - val_loss: 1.9376 - val_accuracy: 0.1471
# Epoch 26/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.9132 - accuracy: 0.2750 - val_loss: 1.9316 - val_accuracy: 0.2059
# Epoch 27/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.9185 - accuracy: 0.1750 - val_loss: 1.9330 - val_accuracy: 0.2059
# Epoch 28/220
# 4/4 [==============================] - 2s 495ms/step - loss: 1.9171 - accuracy: 0.2000 - val_loss: 1.9365 - val_accuracy: 0.1765
# Epoch 29/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.9163 - accuracy: 0.2500 - val_loss: 1.9326 - val_accuracy: 0.2059
# Epoch 30/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.9081 - accuracy: 0.3429 - val_loss: 1.9269 - val_accuracy: 0.2353
# Epoch 31/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.9088 - accuracy: 0.2750 - val_loss: 1.9294 - val_accuracy: 0.1471
# Epoch 32/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.9060 - accuracy: 0.3250 - val_loss: 1.9300 - val_accuracy: 0.1176
# Epoch 33/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.9093 - accuracy: 0.2000 - val_loss: 1.9266 - val_accuracy: 0.1765
# Epoch 34/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.9073 - accuracy: 0.3250 - val_loss: 1.9287 - val_accuracy: 0.1176
# Epoch 35/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.9016 - accuracy: 0.3500 - val_loss: 1.9245 - val_accuracy: 0.1471
# Epoch 36/220
# 4/4 [==============================] - 2s 439ms/step - loss: 1.9040 - accuracy: 0.3714 - val_loss: 1.9124 - val_accuracy: 0.2059
# Epoch 37/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8927 - accuracy: 0.3000 - val_loss: 1.9200 - val_accuracy: 0.2353
# Epoch 38/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.9008 - accuracy: 0.3250 - val_loss: 1.9172 - val_accuracy: 0.2647
# Epoch 39/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8998 - accuracy: 0.2857 - val_loss: 1.9158 - val_accuracy: 0.2059
# Epoch 40/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.9009 - accuracy: 0.3750 - val_loss: 1.9246 - val_accuracy: 0.2647
# Epoch 41/220
# 4/4 [==============================] - 2s 443ms/step - loss: 1.8938 - accuracy: 0.3143 - val_loss: 1.9131 - val_accuracy: 0.2059
# Epoch 42/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8975 - accuracy: 0.3250 - val_loss: 1.9140 - val_accuracy: 0.1765
# Epoch 43/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8911 - accuracy: 0.3000 - val_loss: 1.9037 - val_accuracy: 0.1765
# Epoch 44/220
# 4/4 [==============================] - 2s 440ms/step - loss: 1.8833 - accuracy: 0.3714 - val_loss: 1.9063 - val_accuracy: 0.1176
# Epoch 45/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8866 - accuracy: 0.4000 - val_loss: 1.9059 - val_accuracy: 0.1765
# Epoch 46/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8829 - accuracy: 0.3500 - val_loss: 1.8949 - val_accuracy: 0.2941
# Epoch 47/220
# 4/4 [==============================] - 2s 443ms/step - loss: 1.8778 - accuracy: 0.4000 - val_loss: 1.9033 - val_accuracy: 0.1765
# Epoch 48/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.8822 - accuracy: 0.3000 - val_loss: 1.9012 - val_accuracy: 0.1765
# Epoch 49/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8667 - accuracy: 0.4250 - val_loss: 1.8992 - val_accuracy: 0.2059
# Epoch 50/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8706 - accuracy: 0.5143 - val_loss: 1.8699 - val_accuracy: 0.2647
# Epoch 51/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8734 - accuracy: 0.2750 - val_loss: 1.8856 - val_accuracy: 0.2647
# Epoch 52/220
# 4/4 [==============================] - 2s 441ms/step - loss: 1.8744 - accuracy: 0.3714 - val_loss: 1.8743 - val_accuracy: 0.2059
# Epoch 53/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8806 - accuracy: 0.2000 - val_loss: 1.8893 - val_accuracy: 0.2059
# Epoch 54/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.8588 - accuracy: 0.4250 - val_loss: 1.8806 - val_accuracy: 0.2353
# Epoch 55/220
# 4/4 [==============================] - 2s 444ms/step - loss: 1.8601 - accuracy: 0.3429 - val_loss: 1.8984 - val_accuracy: 0.1765
# Epoch 56/220
# 4/4 [==============================] - 2s 496ms/step - loss: 1.8615 - accuracy: 0.3500 - val_loss: 1.8778 - val_accuracy: 0.2353
# Epoch 57/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8578 - accuracy: 0.3750 - val_loss: 1.8807 - val_accuracy: 0.2059
# Epoch 58/220
# 4/4 [==============================] - 2s 443ms/step - loss: 1.8654 - accuracy: 0.3429 - val_loss: 1.9012 - val_accuracy: 0.1471
# Epoch 59/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8772 - accuracy: 0.2250 - val_loss: 1.8545 - val_accuracy: 0.2059
# Epoch 60/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.8416 - accuracy: 0.4750 - val_loss: 1.8751 - val_accuracy: 0.1471
# Epoch 61/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8452 - accuracy: 0.3714 - val_loss: 1.8696 - val_accuracy: 0.2059
# Epoch 62/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.8621 - accuracy: 0.2750 - val_loss: 1.8608 - val_accuracy: 0.2059
# Epoch 63/220
# 4/4 [==============================] - 2s 443ms/step - loss: 1.8444 - accuracy: 0.4857 - val_loss: 1.8502 - val_accuracy: 0.2941
# Epoch 64/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.8519 - accuracy: 0.4000 - val_loss: 1.8714 - val_accuracy: 0.1765
# Epoch 65/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.8363 - accuracy: 0.4250 - val_loss: 1.8610 - val_accuracy: 0.2353
# Epoch 66/220
# 4/4 [==============================] - 2s 443ms/step - loss: 1.8461 - accuracy: 0.2857 - val_loss: 1.8364 - val_accuracy: 0.2353
# Epoch 67/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8489 - accuracy: 0.2500 - val_loss: 1.8744 - val_accuracy: 0.2059
# Epoch 68/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.8195 - accuracy: 0.4250 - val_loss: 1.8625 - val_accuracy: 0.2941
# Epoch 69/220
# 4/4 [==============================] - 2s 444ms/step - loss: 1.8293 - accuracy: 0.3429 - val_loss: 1.8532 - val_accuracy: 0.2353
# Epoch 70/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.8333 - accuracy: 0.3500 - val_loss: 1.8966 - val_accuracy: 0.2059
# Epoch 71/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8273 - accuracy: 0.3750 - val_loss: 1.8494 - val_accuracy: 0.2353
# Epoch 72/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.8220 - accuracy: 0.2857 - val_loss: 1.8129 - val_accuracy: 0.3235
# Epoch 73/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8272 - accuracy: 0.4000 - val_loss: 1.8393 - val_accuracy: 0.2647
# Epoch 74/220
# 4/4 [==============================] - 2s 443ms/step - loss: 1.8161 - accuracy: 0.3429 - val_loss: 1.8230 - val_accuracy: 0.2353
# Epoch 75/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8019 - accuracy: 0.3500 - val_loss: 1.8599 - val_accuracy: 0.2647
# Epoch 76/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.8324 - accuracy: 0.3750 - val_loss: 1.8247 - val_accuracy: 0.2647
# Epoch 77/220
# 4/4 [==============================] - 2s 444ms/step - loss: 1.8501 - accuracy: 0.2571 - val_loss: 1.8359 - val_accuracy: 0.2353
# Epoch 78/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.8045 - accuracy: 0.4000 - val_loss: 1.7935 - val_accuracy: 0.2059
# Epoch 79/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.7993 - accuracy: 0.4250 - val_loss: 1.8285 - val_accuracy: 0.2647
# Epoch 80/220
# 4/4 [==============================] - 2s 440ms/step - loss: 1.8085 - accuracy: 0.3429 - val_loss: 1.8296 - val_accuracy: 0.2353
# Epoch 81/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.8132 - accuracy: 0.3000 - val_loss: 1.8303 - val_accuracy: 0.2353
# Epoch 82/220
# 4/4 [==============================] - 2s 497ms/step - loss: 1.7956 - accuracy: 0.3500 - val_loss: 1.8365 - val_accuracy: 0.2059
# Epoch 83/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.8047 - accuracy: 0.3143 - val_loss: 1.8503 - val_accuracy: 0.2941
# Epoch 84/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7883 - accuracy: 0.3750 - val_loss: 1.8235 - val_accuracy: 0.2059
# Epoch 85/220
# 4/4 [==============================] - 2s 444ms/step - loss: 1.8127 - accuracy: 0.3143 - val_loss: 1.8238 - val_accuracy: 0.2353
# Epoch 86/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.8135 - accuracy: 0.2750 - val_loss: 1.8544 - val_accuracy: 0.1765
# Epoch 87/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7711 - accuracy: 0.3750 - val_loss: 1.8458 - val_accuracy: 0.2353
# Epoch 88/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.7842 - accuracy: 0.4000 - val_loss: 1.8126 - val_accuracy: 0.2647
# Epoch 89/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.8091 - accuracy: 0.3500 - val_loss: 1.8194 - val_accuracy: 0.2353
# Epoch 90/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7715 - accuracy: 0.4250 - val_loss: 1.8435 - val_accuracy: 0.2059
# Epoch 91/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.7854 - accuracy: 0.4000 - val_loss: 1.8155 - val_accuracy: 0.2059
# Epoch 92/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7733 - accuracy: 0.4000 - val_loss: 1.8169 - val_accuracy: 0.2353
# Epoch 93/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7692 - accuracy: 0.4000 - val_loss: 1.8124 - val_accuracy: 0.2353
# Epoch 94/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.8062 - accuracy: 0.2571 - val_loss: 1.8144 - val_accuracy: 0.2059
# Epoch 95/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7399 - accuracy: 0.4750 - val_loss: 1.7505 - val_accuracy: 0.1765
# Epoch 96/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.7980 - accuracy: 0.3143 - val_loss: 1.8430 - val_accuracy: 0.2647
# Epoch 97/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.7769 - accuracy: 0.4250 - val_loss: 1.8048 - val_accuracy: 0.2353
# Epoch 98/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7898 - accuracy: 0.3750 - val_loss: 1.8253 - val_accuracy: 0.2353
# Epoch 99/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.7596 - accuracy: 0.4286 - val_loss: 1.8283 - val_accuracy: 0.2059
# Epoch 100/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7628 - accuracy: 0.4000 - val_loss: 1.7757 - val_accuracy: 0.2059
# Epoch 101/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7478 - accuracy: 0.3750 - val_loss: 1.8005 - val_accuracy: 0.2353
# Epoch 102/220
# 4/4 [==============================] - 2s 444ms/step - loss: 1.7790 - accuracy: 0.3429 - val_loss: 1.8170 - val_accuracy: 0.2941
# Epoch 103/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7521 - accuracy: 0.3250 - val_loss: 1.8742 - val_accuracy: 0.1765
# Epoch 104/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.7577 - accuracy: 0.4000 - val_loss: 1.7869 - val_accuracy: 0.2647
# Epoch 105/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7770 - accuracy: 0.2571 - val_loss: 1.7953 - val_accuracy: 0.2353
# Epoch 106/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.7563 - accuracy: 0.4750 - val_loss: 1.7310 - val_accuracy: 0.3235
# Epoch 107/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.7365 - accuracy: 0.4000 - val_loss: 1.8469 - val_accuracy: 0.2941
# Epoch 108/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7214 - accuracy: 0.4750 - val_loss: 1.7855 - val_accuracy: 0.2647
# Epoch 109/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7185 - accuracy: 0.5000 - val_loss: 1.7902 - val_accuracy: 0.2647
# Epoch 110/220
# 4/4 [==============================] - 2s 444ms/step - loss: 1.7560 - accuracy: 0.3143 - val_loss: 1.8424 - val_accuracy: 0.1765
# Epoch 111/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7148 - accuracy: 0.4500 - val_loss: 1.7856 - val_accuracy: 0.2059
# Epoch 112/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7674 - accuracy: 0.2750 - val_loss: 1.7895 - val_accuracy: 0.2941
# Epoch 113/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.7029 - accuracy: 0.4286 - val_loss: 1.7847 - val_accuracy: 0.2647
# Epoch 114/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7078 - accuracy: 0.4000 - val_loss: 1.7859 - val_accuracy: 0.2059
# Epoch 115/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7174 - accuracy: 0.3750 - val_loss: 1.7733 - val_accuracy: 0.1471
# Epoch 116/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7563 - accuracy: 0.2571 - val_loss: 1.8286 - val_accuracy: 0.2353
# Epoch 117/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.6901 - accuracy: 0.4500 - val_loss: 1.7799 - val_accuracy: 0.2647
# Epoch 118/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.7323 - accuracy: 0.4286 - val_loss: 1.7641 - val_accuracy: 0.3235
# Epoch 119/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7389 - accuracy: 0.3500 - val_loss: 1.8486 - val_accuracy: 0.1765
# Epoch 120/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.6717 - accuracy: 0.6000 - val_loss: 1.7744 - val_accuracy: 0.2941
# Epoch 121/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.7353 - accuracy: 0.2571 - val_loss: 1.7743 - val_accuracy: 0.2941
# Epoch 122/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.7008 - accuracy: 0.3500 - val_loss: 1.8276 - val_accuracy: 0.2647
# Epoch 123/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.7103 - accuracy: 0.4500 - val_loss: 1.7526 - val_accuracy: 0.3235
# Epoch 124/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.6978 - accuracy: 0.4857 - val_loss: 1.7904 - val_accuracy: 0.2353
# Epoch 125/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.7414 - accuracy: 0.3500 - val_loss: 1.7691 - val_accuracy: 0.2941
# Epoch 126/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6904 - accuracy: 0.4250 - val_loss: 1.6778 - val_accuracy: 0.4118
# Epoch 127/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6956 - accuracy: 0.3429 - val_loss: 1.8470 - val_accuracy: 0.2353
# Epoch 128/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7370 - accuracy: 0.4750 - val_loss: 1.7295 - val_accuracy: 0.2941
# Epoch 129/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.7045 - accuracy: 0.2286 - val_loss: 1.7620 - val_accuracy: 0.2941
# Epoch 130/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6989 - accuracy: 0.4000 - val_loss: 1.7679 - val_accuracy: 0.3529
# Epoch 131/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6613 - accuracy: 0.4500 - val_loss: 1.8210 - val_accuracy: 0.1765
# Epoch 132/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.6894 - accuracy: 0.4286 - val_loss: 1.7780 - val_accuracy: 0.2647
# Epoch 133/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6853 - accuracy: 0.4750 - val_loss: 1.7528 - val_accuracy: 0.2941
# Epoch 134/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6779 - accuracy: 0.3500 - val_loss: 1.7434 - val_accuracy: 0.2353
# Epoch 135/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.7267 - accuracy: 0.3429 - val_loss: 1.8045 - val_accuracy: 0.3529
# Epoch 136/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.6525 - accuracy: 0.4750 - val_loss: 1.7541 - val_accuracy: 0.3529
# Epoch 137/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6927 - accuracy: 0.5000 - val_loss: 1.7470 - val_accuracy: 0.3235
# Epoch 138/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.6720 - accuracy: 0.4571 - val_loss: 1.7291 - val_accuracy: 0.3235
# Epoch 139/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.6556 - accuracy: 0.5000 - val_loss: 1.8019 - val_accuracy: 0.3235
# Epoch 140/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.6869 - accuracy: 0.4000 - val_loss: 1.7581 - val_accuracy: 0.3529
# Epoch 141/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.6950 - accuracy: 0.3750 - val_loss: 1.7419 - val_accuracy: 0.3824
# Epoch 142/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6113 - accuracy: 0.5000 - val_loss: 1.6917 - val_accuracy: 0.4118
# Epoch 143/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.6928 - accuracy: 0.3143 - val_loss: 1.7241 - val_accuracy: 0.4118
# Epoch 144/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.6596 - accuracy: 0.4750 - val_loss: 1.6924 - val_accuracy: 0.3529
# Epoch 145/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6840 - accuracy: 0.2750 - val_loss: 1.7391 - val_accuracy: 0.3824
# Epoch 146/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.7428 - accuracy: 0.3143 - val_loss: 1.7374 - val_accuracy: 0.3824
# Epoch 147/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6218 - accuracy: 0.4250 - val_loss: 1.6816 - val_accuracy: 0.3824
# Epoch 148/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.6434 - accuracy: 0.3750 - val_loss: 1.7361 - val_accuracy: 0.4412
# Epoch 149/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6538 - accuracy: 0.4857 - val_loss: 1.7328 - val_accuracy: 0.3824
# Epoch 150/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6289 - accuracy: 0.4250 - val_loss: 1.7289 - val_accuracy: 0.4118
# Epoch 151/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.6890 - accuracy: 0.4286 - val_loss: 1.7828 - val_accuracy: 0.2647
# Epoch 152/220
# 4/4 [==============================] - 2s 498ms/step - loss: 1.7007 - accuracy: 0.4000 - val_loss: 1.7079 - val_accuracy: 0.4118
# Epoch 153/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.5956 - accuracy: 0.4750 - val_loss: 1.7256 - val_accuracy: 0.3824
# Epoch 154/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.6659 - accuracy: 0.3714 - val_loss: 1.6763 - val_accuracy: 0.4412
# Epoch 155/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.6444 - accuracy: 0.5000 - val_loss: 1.7722 - val_accuracy: 0.3529
# Epoch 156/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.6435 - accuracy: 0.4250 - val_loss: 1.7316 - val_accuracy: 0.3235
# Epoch 157/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.5732 - accuracy: 0.4857 - val_loss: 1.7262 - val_accuracy: 0.3824
# Epoch 158/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.6817 - accuracy: 0.4250 - val_loss: 1.7952 - val_accuracy: 0.4118
# Epoch 159/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.6564 - accuracy: 0.5250 - val_loss: 1.7163 - val_accuracy: 0.4118
# Epoch 160/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.5922 - accuracy: 0.5714 - val_loss: 1.7075 - val_accuracy: 0.3529
# Epoch 161/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6523 - accuracy: 0.5250 - val_loss: 1.7176 - val_accuracy: 0.3824
# Epoch 162/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.6710 - accuracy: 0.2571 - val_loss: 1.6056 - val_accuracy: 0.3824
# Epoch 163/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6109 - accuracy: 0.4000 - val_loss: 1.6381 - val_accuracy: 0.3824
# Epoch 164/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.6287 - accuracy: 0.4000 - val_loss: 1.6751 - val_accuracy: 0.3824
# Epoch 165/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.5919 - accuracy: 0.3429 - val_loss: 1.7110 - val_accuracy: 0.3824
# Epoch 166/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5605 - accuracy: 0.5000 - val_loss: 1.6562 - val_accuracy: 0.4118
# Epoch 167/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6337 - accuracy: 0.4000 - val_loss: 1.7379 - val_accuracy: 0.3824
# Epoch 168/220
# 4/4 [==============================] - 2s 443ms/step - loss: 1.6469 - accuracy: 0.3714 - val_loss: 1.7170 - val_accuracy: 0.3529
# Epoch 169/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5855 - accuracy: 0.5000 - val_loss: 1.7035 - val_accuracy: 0.3529
# Epoch 170/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.5902 - accuracy: 0.5500 - val_loss: 1.7510 - val_accuracy: 0.4118
# Epoch 171/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.6287 - accuracy: 0.5429 - val_loss: 1.6955 - val_accuracy: 0.3529
# Epoch 172/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.5605 - accuracy: 0.5750 - val_loss: 1.6811 - val_accuracy: 0.3529
# Epoch 173/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.6036 - accuracy: 0.5143 - val_loss: 1.6936 - val_accuracy: 0.3529
# Epoch 174/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5839 - accuracy: 0.4750 - val_loss: 1.6686 - val_accuracy: 0.3824
# Epoch 175/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6001 - accuracy: 0.5500 - val_loss: 1.8332 - val_accuracy: 0.2647
# Epoch 176/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.6941 - accuracy: 0.3714 - val_loss: 1.6396 - val_accuracy: 0.4412
# Epoch 177/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5753 - accuracy: 0.3750 - val_loss: 1.6858 - val_accuracy: 0.3529
# Epoch 178/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.5881 - accuracy: 0.5000 - val_loss: 1.6270 - val_accuracy: 0.3529
# Epoch 179/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.6428 - accuracy: 0.5143 - val_loss: 1.7159 - val_accuracy: 0.3235
# Epoch 180/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.5965 - accuracy: 0.4250 - val_loss: 1.7078 - val_accuracy: 0.2941
# Epoch 181/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5569 - accuracy: 0.4500 - val_loss: 1.6823 - val_accuracy: 0.3824
# Epoch 182/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6355 - accuracy: 0.5429 - val_loss: 1.6342 - val_accuracy: 0.4118
# Epoch 183/220
# 4/4 [==============================] - 2s 501ms/step - loss: 1.5308 - accuracy: 0.4750 - val_loss: 1.5829 - val_accuracy: 0.4412
# Epoch 184/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.6090 - accuracy: 0.4857 - val_loss: 1.6113 - val_accuracy: 0.4412
# Epoch 185/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.5336 - accuracy: 0.6000 - val_loss: 1.6833 - val_accuracy: 0.4118
# Epoch 186/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.5361 - accuracy: 0.4750 - val_loss: 1.6153 - val_accuracy: 0.4412
# Epoch 187/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.6332 - accuracy: 0.4286 - val_loss: 1.6069 - val_accuracy: 0.5588
# Epoch 188/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.5452 - accuracy: 0.5750 - val_loss: 1.7173 - val_accuracy: 0.4118
# Epoch 189/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5405 - accuracy: 0.5250 - val_loss: 1.6694 - val_accuracy: 0.3529
# Epoch 190/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.5383 - accuracy: 0.6286 - val_loss: 1.6831 - val_accuracy: 0.4118
# Epoch 191/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5065 - accuracy: 0.5750 - val_loss: 1.6457 - val_accuracy: 0.4412
# Epoch 192/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.5869 - accuracy: 0.4500 - val_loss: 1.6897 - val_accuracy: 0.3529
# Epoch 193/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.6316 - accuracy: 0.5143 - val_loss: 1.6615 - val_accuracy: 0.4118
# Epoch 194/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5314 - accuracy: 0.4250 - val_loss: 1.6994 - val_accuracy: 0.3824
# Epoch 195/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.4756 - accuracy: 0.6000 - val_loss: 1.5886 - val_accuracy: 0.3824
# Epoch 196/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.5857 - accuracy: 0.4500 - val_loss: 1.7547 - val_accuracy: 0.3529
# Epoch 197/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5349 - accuracy: 0.4500 - val_loss: 1.6634 - val_accuracy: 0.3824
# Epoch 198/220
# 4/4 [==============================] - 2s 445ms/step - loss: 1.4646 - accuracy: 0.5714 - val_loss: 1.5763 - val_accuracy: 0.3824
# Epoch 199/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5830 - accuracy: 0.3250 - val_loss: 1.6751 - val_accuracy: 0.3529
# Epoch 200/220
# 4/4 [==============================] - 2s 500ms/step - loss: 1.5359 - accuracy: 0.4000 - val_loss: 1.6715 - val_accuracy: 0.2941
# Epoch 201/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.4579 - accuracy: 0.5714 - val_loss: 1.6472 - val_accuracy: 0.3529
# Epoch 202/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.6044 - accuracy: 0.4000 - val_loss: 1.6491 - val_accuracy: 0.2941
# Epoch 203/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.4680 - accuracy: 0.5000 - val_loss: 1.6863 - val_accuracy: 0.3529
# Epoch 204/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.5484 - accuracy: 0.4571 - val_loss: 1.5946 - val_accuracy: 0.4412
# Epoch 205/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.5744 - accuracy: 0.3500 - val_loss: 1.6384 - val_accuracy: 0.4118
# Epoch 206/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.4868 - accuracy: 0.5143 - val_loss: 1.6048 - val_accuracy: 0.5294
# Epoch 207/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.4934 - accuracy: 0.5250 - val_loss: 1.5866 - val_accuracy: 0.4412
# Epoch 208/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.5139 - accuracy: 0.3250 - val_loss: 1.6511 - val_accuracy: 0.4118
# Epoch 209/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.5749 - accuracy: 0.4571 - val_loss: 1.6376 - val_accuracy: 0.3529
# Epoch 210/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.4650 - accuracy: 0.4750 - val_loss: 1.7141 - val_accuracy: 0.2941
# Epoch 211/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5472 - accuracy: 0.5500 - val_loss: 1.5096 - val_accuracy: 0.3529
# Epoch 212/220
# 4/4 [==============================] - 2s 442ms/step - loss: 1.4933 - accuracy: 0.5143 - val_loss: 1.6747 - val_accuracy: 0.2941
# Epoch 213/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.5027 - accuracy: 0.5250 - val_loss: 1.6513 - val_accuracy: 0.3824
# Epoch 214/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.5564 - accuracy: 0.4500 - val_loss: 1.6441 - val_accuracy: 0.3529
# Epoch 215/220
# 4/4 [==============================] - 2s 502ms/step - loss: 1.4872 - accuracy: 0.3714 - val_loss: 1.5998 - val_accuracy: 0.5294
# Epoch 216/220
# 4/4 [==============================] - 2s 499ms/step - loss: 1.5196 - accuracy: 0.4500 - val_loss: 1.6806 - val_accuracy: 0.3824
# Epoch 217/220
# 4/4 [==============================] - 2s 446ms/step - loss: 1.5065 - accuracy: 0.4857 - val_loss: 1.6400 - val_accuracy: 0.3824
# Epoch 218/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.4469 - accuracy: 0.4750 - val_loss: 1.6541 - val_accuracy: 0.3824
# Epoch 219/220
# 4/4 [==============================] - 2s 503ms/step - loss: 1.5160 - accuracy: 0.5250 - val_loss: 1.6103 - val_accuracy: 0.3529
# Epoch 220/220
# 4/4 [==============================] - 2s 444ms/step - loss: 1.5065 - accuracy: 0.5143 - val_loss: 1.6075 - val_accuracy: 0.4412

# %%
model.save(currentPath + os.sep + "DenseNet161Model.h5")
model.save_weights(currentPath + os.sep + "DenseNet161Weights.h5")

# %%
# Lets plot the results
print(history.history.keys())
# history accuracy
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("model accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.grid()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# history accuracy
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.grid()
plt.show()

# %%
# Lets predict
path = valDB + os.sep + "airport" + os.sep
imagesPredict = [f for f in listdir(path) if isfile(join(path,f))]

for file in imagesPredict:
    img = load_img(path + file, target_size=( 224, 224))
    tensorImage = img_to_array(img) /255.
    tensorImage = np.expand_dims(tensorImage, axis=0)
    prediction = model.predict(tensorImage, batch_size = 1)
    index = np.where(prediction[0] == max(prediction[0]))[0]
    if (0 != index[0].size):
        print("file "+ file + " is: " + classList[int(index[0])])
# Out:
# file airport_26_1_msrgb.jpg is: airport
# file airport_45_3_msrgb.jpg is: airport
# file airport_55_0_msrgb.jpg is: airport
# file airport_6_0_msrgb.jpg is: airport

# %%
loadedModel = load_model("DenseNet161Model.h5")

path = valDB + os.sep + "airport" + os.sep
imagesPredict = [f for f in listdir(path) if isfile(join(path,f))]
# print(imagesPredict)


for file in imagesPredict:
    img = load_img(path + file, target_size=( 224, 224))
    tensorImage = img_to_array(img) /255.
    tensorImage = np.expand_dims(tensorImage, axis=0)
    prediction = loadedModel.predict(tensorImage, batch_size = 1)
    index = np.where(prediction[0] == max(prediction[0]))[0]
    if (0 != index[0].size):
        print("file "+ file + " is: " + classList[int(index[0])])
# Out:
# file airport_26_1_msrgb.jpg is: airport
# file airport_45_3_msrgb.jpg is: airport
# file airport_55_0_msrgb.jpg is: airport
# file airport_6_0_msrgb.jpg is: airport
